# %% [markdown]
# <a href="https://colab.research.google.com/github/rickosiregar/ETL-SCRAPING/blob/main/Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import logging

logging.basicConfig(level=logging.INFO)

# %%
url = "https://id.wikipedia.org/wiki/Daftar_negara_penghasil_komoditas_agrikultural_terbesar"

# %%
def scrape(url):
  logging.info(f"Scraping website url: '{url}'....")
  return pd.read_html(url, header=None)

# %%
df = scrape(url)[0]

# %%
df
# Out:
#    Jenis komoditas Pertama (Penghasil terbesar)            Kedua     Ketiga
# 0    Gandum barley                        Rusia           Jerman    Prancis
# 1           Jagung              Amerika Serikat         Tiongkok     Brasil
# 2       Gandum oat                        Rusia           Kanada  Finlandia
# 3            Beras                     Tiongkok            India  Indonesia
# 4           Sorgum              Amerika Serikat          Meksiko    Nigeria
# ..             ...                          ...              ...        ...
# 68          Vanili                    Indonesia       Madagaskar        NaN
# 69           Kakao                Pantai Gading            Ghana  Indonesia
# 70           Telur                     Tiongkok  Amerika Serikat      India
# 71            Madu                     Tiongkok            Turki  Argentina
# 72        Tembakau                     Tiongkok           Brasil      India
#
# [73 rows x 4 columns]

# %%
df.to_excel ('Komoditas_Dunia.xlsx')

# %%
url = "https://id.wikipedia.org/wiki/Komoditas"

# %%
def scrape(url):
  logging.info(f"Scraping website url: '{url}'....")
  return pd.read_html(url, header=None)

# %%
df2 = scrape(url)[1]

# %%
df2
# Out:
#                                            Komoditas                  Satuan  \
# 0                                     Kopi (Robusta)                     ton
# 1                                     Kopi (Arabika)                    1 lb
# 2                                               Gula                     ton
# 3                                               Gula                   1 pon
# 4                                             Coklat             1 short ton
# 5                                             coklat                     ton
# 6                                   maizena (jagung)       gantang (=56 pon)
# 7                                              beras  2,000 cwt (200,000 lb)
# 8                                            kedelai        gantang (=60 lb)
# 9                                     kacang kedelai               short ton
# 10                                    minyak kedelai  short hundredweight[2]
# ...

# %%
df.to_excel ('Komoditas_Indonesia.xlsx')

# %%
url = "https://satudata.kemendag.go.id/data-informasi/perdagangan-luar-negeri/ekspor-non-migas-sektor"

# %%
def scrape(url):
  logging.info(f"Scraping website url: '{url}'....")
  return pd.read_html(url, header=None)

# %%
df3 = scrape(url)[1]

# %%
df3
# Out:
#      HS                        URAIAN      2017      2018      2019      2020  \
#      HS                        URAIAN      2017      2018      2019      2020
# 0   NaN                     NON MIGAS  153083.8  162840.9  155893.7  154940.8
# 1   NaN                       LAINNYA       5.8       5.8       6.7       5.0
# 2  40.0   KARET DAN BARANG DARI KARET       5.7       5.8       6.6       5.0
# 3  89.0                    KAPAL LAUT       0.1       0.0       0.0       0.0
# 4  27.0           BAHAN BAKAR MINERAL       0.0       0.0       0.0       0.0
# 5  26.0  BIJIH, KERAK,, DAN ABU LOGAM       0.0       0.0       0.0       0.0
#
#        2021 Trend (%) 2017 - 2021 Perub (%) 2021 - 2020 Peran (%) 2021  \
#        2021 Trend (%) 2017 - 2021 Perub (%) 2021 - 2020 Peran (%) 2021
# 0  219362.1                  6.93                 41.58          100.0
# 1       7.4                  3.37                 49.89            0.0
# ...
